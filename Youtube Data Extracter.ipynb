# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
from apiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
CLIENT_SECRET_FILE = "client_secret.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']

# %%
#flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_FILE,SCOPES)
#credentials = flow.run_console()
#youtube = build('youtube','v3',credentials=credentials)

# %%
api_key = "AIzaSyBo2VkS25wyWISE21BF2neYYL_R89HHYF0"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3',developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req = youtube.search().list(q='avengers',part='snippet',type='video',maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()

# %%
res['items']
# Out:
# [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/_NyYllRt8F8COZm6OLzQ4rDzKJM"',
#   'id': {'kind': 'youtube#video', 'videoId': 'SLD9xzJ4oeU'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UClVbhSLxwws-KSsPKz135bw',
#    'channelTitle': 'TopMovieClips',
#    'description': 'Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip 1080p HD All material belongs to Disney and Marvel. Fair use. Copyright Disclaimer Under Section ...',
#    'liveBroadcastContent': 'none',
#    'publishedAt': '2017-01-22T21:08:03.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/SLD9xzJ4oeU/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/SLD9xzJ4oeU/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/SLD9xzJ4oeU/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip HD'}},
# ...

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip HD
# Avengers: Endgame but only Best Scenes [4K UHD]
# Avengers Endgame Deleted Scene - Iron Man Alternate Ending Scene Breakdown
# Iron Man Vs Thanos - Fight Scene - Avengers Infinity War (2018) Movie CLIP HD
# Marvel Studios’ Avengers: Damage Control - Official Teaser Trailer
# The Avengers (2012) Hindi Avengers Are Ready For The Battle
# The Avengers - &quot;I&#39;m Always Angry&quot; - Hulk SMASH Scene - Movie CLIP HD
# Avengers, Fidget Spinner Go~! Hulk, Spider-Man, Iron Man, Captain America, Bumblebee, Transformer
# Avengers Infinity War - Thor Vs Thanos Fight Scenes | Avengers 4 - All Death Scenes [Full HD]
# Lady Avengers : Infinity War Characters ( Gender Swap )
# What If &quot;Avengers: Endgame&quot; Had A Dark Ending? - IRON MAN vs. THANOS (Fight Scene)
# Team Iron Man vs Team Cap - Airport Battle Scene - Captain America: Civil War - Movie CLIP HD
# ...

# %%
res1 = youtube.search().list(part='snippet',q='python programming',maxResults=50,type='video',
                            publishedAfter=start_time,
                            publishedBefore=end_time).execute()

# %%
for item in sorted(res1['items'], key=lambda x:x['snippet']['publishedAt']):
    print(item['snippet']['title'],item['snippet']['publishedAt'])
# Out:
# Python Reality Hack 003 2007-03-19T22:39:49.000Z
# Parse and print XML file in python- Codeitch 2007-04-12T12:41:07.000Z
# Python 1: Installation and beginner&#39;s tutorial. 2007-05-03T08:55:29.000Z
# Python 2: Getting around Python modules 2007-05-06T00:12:05.000Z
# Lesson 3 - Interactive Programming 2007-07-16T02:31:12.000Z
# Bay Area Python Interest Group April Meeting: Snippets 2007-07-16T18:35:57.000Z
# Python 3000 2007-07-23T20:58:48.000Z
# First 5 Minutes Programming with Python 2007-08-11T14:23:50.000Z
# python 1 Minutes Programming with PARDUS 2007-08-25T00:51:30.000Z
# Python 3000 2007-10-09T02:26:35.000Z
# Python 3000 2007-10-09T02:37:33.000Z
# Advanced Topics in Programming Languages Series: Python... 2007-10-09T02:38:22.000Z
# Advanced Python or Understanding Python 2007-10-09T02:44:57.000Z
# Advanced Topics in Programming Languages Series: Python... 2007-10-09T02:47:41.000Z
# ReUsable Web Components with Python and Future Python Web... 2007-10-09T03:29:05.000Z
# ...

# %%
res1
# Out:
# {'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/NHsRmVbzd9uFrzZPWCsJ5qsdHUE"',
#  'items': [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/bvb1to3ltQZUbugBHteKGt5YcZY"',
#    'id': {'kind': 'youtube#video', 'videoId': 'E_kZDvwofHY'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCtXKDgv1AVoG88PLl8nGXmw',
#     'channelTitle': 'GoogleTechTalks',
#     'description': 'Google Tech Talks February 21, 2007 ABSTRACT The Python language, while object-oriented, is fundamentally different from both C++ and Java. The dynamic ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2007-10-09T02:44:57.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/E_kZDvwofHY/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/E_kZDvwofHY/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/E_kZDvwofHY/mqdefault.jpg',
# ...

# %%
from datetime import datetime

# %%
start_time = datetime(year=2005, month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year=2009, month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
